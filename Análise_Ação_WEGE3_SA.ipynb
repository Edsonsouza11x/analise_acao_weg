# %% [markdown]
# <a href="https://colab.research.google.com/github/Edsonsouza11x/analise_acao_weg/blob/main/An%C3%A1lise_A%C3%A7%C3%A3o_WEGE3_SA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise da Ação WEGE3.SA
#
# A ação da WEGE3.SA, da Weg S.A., empresa brasileira de bens de capital, vem apresentando um forte desempenho nos últimos anos. Desde 2018, a ação registrou um retorno simples de 267,87%, com uma média de retorno diário de 0,12%. Isso significa que, se um investidor tivesse comprado uma ação da Weg em 2018 por R$ 100, ela estaria valendo R$ 367,87 em setembro de 2023.
#
# A taxa de retorno anual da ação da Weg é de 29,41%. Isso significa que, se um investidor tivesse comprado uma ação da Weg em 2018 e mantido por um ano, ele teria obtido um retorno de 29,41%.
#
# Além do retorno simples, é importante considerar também o retorno logarítmico. O retorno logarítmico é uma medida de retorno que leva em consideração o efeito da inflação. O retorno logarítmico da ação da Weg é de 130,25%, com uma média de retorno diário de 0,09%. Isso significa que, se um investidor tivesse comprado uma ação da Weg em 2018 e mantido por um ano, ele teria obtido um retorno real de 130,25%.
#
# O desempenho da ação da Weg é reflexo do bom momento da empresa. A Weg é uma das líderes mundiais na fabricação de motores elétricos, transformadores e geradores. A empresa vem crescendo a um ritmo acelerado nos últimos anos, impulsionada pela demanda global por energia limpa e renovável.
#
# No futuro, a Weg deve continuar a crescer, impulsionada por tendências como a eletrificação, a energia renovável e a indústria 4.0. Isso deve continuar a beneficiar a ação da empresa, o que pode gerar retornos atraentes para os investidores.
#
# Aqui estão alguns fatores que podem contribuir para o crescimento da Weg no futuro:
#
# * A crescente demanda global por energia limpa e renovável;
# * O avanço da eletrificação da indústria;
# * A expansão da indústria 4.0;
# * A consolidação do setor de bens de capital no Brasil.
#
#
#
# # Informações sobre a Ação da WEGE3.SA
#
# A ação WEGE3.SA refere-se à ação ordinária da WEG S.A., uma das maiores empresas brasileiras no setor de equipamentos elétricos e eletrônicos. A WEG é conhecida por fabricar uma ampla gama de produtos, incluindo motores elétricos, transformadores, geradores, painéis elétricos, automação industrial, e produtos relacionados à eficiência energética.
#
# Aqui estão algumas informações-chave sobre a ação WEGE3.SA:
#
# 1. Setor: A WEG atua no setor de equipamentos elétricos e eletrônicos, fornecendo soluções para diversos segmentos da indústria, incluindo manufatura, petróleo e gás, mineração, infraestrutura, energia renovável e muitos outros.
#
# 2. Negociação: A ação WEGE3.SA é negociada na B3 (Bolsa de Valores do Brasil), permitindo que os investidores comprem e vendam ações da empresa no mercado secundário.
#
# 3. Performance: A WEG é uma das empresas mais reconhecidas e respeitadas do Brasil, e suas ações têm sido historicamente populares entre os investidores. O desempenho da empresa e de suas ações está sujeito às condições do mercado, à economia global e a eventos específicos relacionados à empresa.
#
# 4. Dividendos: A WEG tem um histórico de pagamento de dividendos aos acionistas, o que a torna uma opção atraente para investidores que buscam renda passiva.
#
# 5. Pesquisa: Antes de investir em ações da WEG ou de qualquer outra empresa, é importante realizar uma análise detalhada, considerando os fundamentos da empresa, seu histórico de desempenho, concorrência e perspectivas futuras. Além disso, é recomendável diversificar seus investimentos para mitigar riscos.
#
# Lembre-se de que investir em ações envolve riscos, e o valor das ações pode flutuar significativamente ao longo do tempo.

# %%
# !pip install yfinance

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np
from pandas_datareader import data
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import yfinance as yf
import plotly.graph_objects as go

# %% [markdown]
# ## Base de dados

# %%
# wege_df = data.DataReader(name = 'ALUP11.SA', data_source='yahoo', start='2018-01-01')
wege_df = yf.download("WEGE3.SA", start='2018-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
wege_df
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-01-02   9.365384   9.680769   9.365384   9.623076   8.858922   4812860
# 2018-01-03   9.576923   9.596153   9.457692   9.476923   8.724376   4652960
# 2018-01-04   9.530769   9.584615   9.384615   9.384615   8.639397   3317600
# 2018-01-05   9.469230   9.480769   9.342307   9.423076   8.674805   2552680
# 2018-01-08   9.426923   9.557692   9.253846   9.500000   8.745617   3346200
# ...               ...        ...        ...        ...        ...       ...
# 2023-09-01  35.759998  36.209999  35.570000  35.950001  35.950001  10375300
# 2023-09-04  36.099998  36.130001  35.580002  36.130001  36.130001   3994000
# 2023-09-05  36.000000  36.340000  35.740002  35.910000  35.910000   4331200
# 2023-09-06  35.939999  36.310001  35.549999  35.549999  35.549999   4726300
# 2023-09-08  35.549999  35.630001  35.110001  35.400002  35.400002   4376200
#
# [1412 rows x 6 columns]

# %%
wege_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1412 entries, 2018-01-02 to 2023-09-08
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1412 non-null   float64
#  1   High       1412 non-null   float64
#  2   Low        1412 non-null   float64
#  3   Close      1412 non-null   float64
#  4   Adj Close  1412 non-null   float64
#  5   Volume     1412 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 77.2 KB

# %%
wege_df.head(3)
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 2018-01-02  9.365384  9.680769  9.365384  9.623076   8.858922  4812860
# 2018-01-03  9.576923  9.596153  9.457692  9.476923   8.724376  4652960
# 2018-01-04  9.530769  9.584615  9.384615  9.384615   8.639397  3317600

# %%
wege_df.tail(3)
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2023-09-05  36.000000  36.340000  35.740002  35.910000  35.910000  4331200
# 2023-09-06  35.939999  36.310001  35.549999  35.549999  35.549999  4726300
# 2023-09-08  35.549999  35.630001  35.110001  35.400002  35.400002  4376200

# %%
wege_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1412.000000  1412.000000  1412.000000  1412.000000  1412.000000
# mean     25.110045    25.511515    24.709208    25.093999    24.312081
# std      12.364594    12.545496    12.167132    12.351660    12.237828
# min       7.575000     7.720000     7.535000     7.605000     7.042079
# 25%       9.932500    10.046635     9.816923     9.955769     9.228474
# 50%      28.960000    29.330000    28.490000    28.940001    28.357912
# 75%      36.502500    36.991251    35.913750    36.450001    35.614520
# max      46.459999    46.930000    44.799999    46.105000    44.230762
#
#              Volume
# count  1.412000e+03
# mean   8.306832e+06
# std    4.559988e+06
# min    0.000000e+00
# 25%    5.344105e+06
# 50%    7.218600e+06
# 75%    1.013678e+07
# max    4.393400e+07

# %%
wege_df[wege_df['Close'] >= 46.00]
# Out:
#                  Open       High        Low   Close  Adj Close    Volume
# Date
# 2021-01-18  43.424999  46.154999  43.400002  46.105  44.230762  14797400

# %%
wege_df[(wege_df['Close'] >= 42.15) & (wege_df['Close'] <= 46.14)]
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-11-05  41.950001  42.875000  41.849998  42.875000  41.111244  17481600
# 2021-01-07  41.189999  42.505001  40.919998  42.330002  40.609222  15129600
# 2021-01-08  42.474998  44.994999  42.424999  44.889999  43.065155  17381000
# 2021-01-11  44.485001  45.220001  43.134998  43.514999  41.746048  15490800
# 2021-01-12  43.715000  45.419998  43.294998  45.035000  43.204254  12690600
# 2021-01-13  45.099998  45.955002  44.404999  45.139999  43.304996  13782800
# 2021-01-14  45.580002  45.715000  44.799999  44.935001  43.108326   8477000
# 2021-01-15  44.625000  45.465000  42.705002  43.080002  41.328739  14086600
# 2021-01-18  43.424999  46.154999  43.400002  46.105000  44.230762  14797400
# 2021-01-19  46.459999  46.930000  44.525002  44.799999  42.978813  13788600
# 2021-01-20  45.275002  45.709999  44.205002  44.349998  42.547108   7016400
# ...

# %%
wege_df.to_csv('wege.csv')

# %%
wege_df2 = pd.read_csv('/content/wege.csv')
wege_df2
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2018-01-02   9.365384   9.680769   9.365384   9.623076   8.858922
# 1     2018-01-03   9.576923   9.596153   9.457692   9.476923   8.724376
# 2     2018-01-04   9.530769   9.584615   9.384615   9.384615   8.639397
# 3     2018-01-05   9.469230   9.480769   9.342307   9.423076   8.674805
# 4     2018-01-08   9.426923   9.557692   9.253846   9.500000   8.745617
# ...          ...        ...        ...        ...        ...        ...
# 1407  2023-09-01  35.759998  36.209999  35.570000  35.950001  35.950001
# 1408  2023-09-04  36.099998  36.130001  35.580002  36.130001  36.130001
# 1409  2023-09-05  36.000000  36.340000  35.740002  35.910000  35.910000
# 1410  2023-09-06  35.939999  36.310001  35.549999  35.549999  35.549999
# 1411  2023-09-08  35.549999  35.630001  35.110001  35.400002  35.400002
#
#         Volume
# 0      4812860
# 1      4652960
# 2      3317600
# 3      2552680
# 4      3346200
# ...

# %% [markdown]
# #Taxa de Retorno Simples

# %%
len(wege_df2)
# Out:
# 1412

# %%
wege_df['Close'][0], wege_df['Close'][len(wege_df) - 1]
# Out:
# (9.623076438903809, 35.400001525878906)

# %%
((wege_df['Close'][len(wege_df) - 1] - wege_df['Close'][0]) / wege_df['Close'][0]) * 100
# Out:
# 267.8657417992143

# %%
(wege_df['Close'][len(wege_df) - 1] / wege_df['Close'][0] - 1) * 100
# Out:
# 267.8657417992143

# %% [markdown]
# #Taxa de Retorno Diária

# %%
wege_df['Close']
# Out:
# Date
# 2018-01-02     9.623076
# 2018-01-03     9.476923
# 2018-01-04     9.384615
# 2018-01-05     9.423076
# 2018-01-08     9.500000
#                 ...
# 2023-09-01    35.950001
# 2023-09-04    36.130001
# 2023-09-05    35.910000
# 2023-09-06    35.549999
# 2023-09-08    35.400002
# Name: Close, Length: 1412, dtype: float64

# %%
wege_df['Close'].shift(1)
# Out:
# Date
# 2018-01-02          NaN
# 2018-01-03     9.623076
# 2018-01-04     9.476923
# 2018-01-05     9.384615
# 2018-01-08     9.423076
#                 ...
# 2023-09-01    35.880001
# 2023-09-04    35.950001
# 2023-09-05    36.130001
# 2023-09-06    35.910000
# 2023-09-08    35.549999
# Name: Close, Length: 1412, dtype: float64

# %%
wege_df['RS Close'] = (wege_df['Close'] / wege_df['Close'].shift(1)) - 1

# %%
wege_df
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-02   9.365384   9.680769   9.365384   9.623076   8.858922   4812860
# 2018-01-03   9.576923   9.596153   9.457692   9.476923   8.724376   4652960
# 2018-01-04   9.530769   9.584615   9.384615   9.384615   8.639397   3317600
# 2018-01-05   9.469230   9.480769   9.342307   9.423076   8.674805   2552680
# 2018-01-08   9.426923   9.557692   9.253846   9.500000   8.745617   3346200
# ...               ...        ...        ...        ...        ...       ...
# 2023-09-01  35.759998  36.209999  35.570000  35.950001  35.950001  10375300
# 2023-09-04  36.099998  36.130001  35.580002  36.130001  36.130001   3994000
# 2023-09-05  36.000000  36.340000  35.740002  35.910000  35.910000   4331200
# 2023-09-06  35.939999  36.310001  35.549999  35.549999  35.549999   4726300
# 2023-09-08  35.549999  35.630001  35.110001  35.400002  35.400002   4376200
#
#             RS Close
# Date
# ...

# %%
wege_df['RS Close'].plot();

# %%
#Média diária de retorno
wege_df['RS Close'].mean()
# Out:
# 0.0011953989086056125

# %%
wege_df['RS Close'].mean() * 100
# Out:
# 0.11953989086056124

# %% [markdown]
# #Taxa de Retorno Anual

# %%
(wege_df['RS Close'].mean() * 246) * 100
# Out:
# 29.40681315169807

# %% [markdown]
# #Taxa de Retorno Logarítmica

# %%
wege_df['Close'][0], wege_df['Close'][len(wege_df) - 1]
# Out:
# (9.623076438903809, 35.400001525878906)

# %%
np.log(wege_df['Close'][len(wege_df) - 1] / wege_df['Close'][0]) * 100
# Out:
# 130.25478535460772

# %%
wege_df['RL Close'] = np.log(wege_df['Close'] / wege_df['Close'].shift(1))
wege_df
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-02   9.365384   9.680769   9.365384   9.623076   8.858922   4812860
# 2018-01-03   9.576923   9.596153   9.457692   9.476923   8.724376   4652960
# 2018-01-04   9.530769   9.584615   9.384615   9.384615   8.639397   3317600
# 2018-01-05   9.469230   9.480769   9.342307   9.423076   8.674805   2552680
# 2018-01-08   9.426923   9.557692   9.253846   9.500000   8.745617   3346200
# ...               ...        ...        ...        ...        ...       ...
# 2023-09-01  35.759998  36.209999  35.570000  35.950001  35.950001  10375300
# 2023-09-04  36.099998  36.130001  35.580002  36.130001  36.130001   3994000
# 2023-09-05  36.000000  36.340000  35.740002  35.910000  35.910000   4331200
# 2023-09-06  35.939999  36.310001  35.549999  35.549999  35.549999   4726300
# 2023-09-08  35.549999  35.630001  35.110001  35.400002  35.400002   4376200
#
#             RS Close  RL Close
# Date
# ...

# %%
wege_df['RL Close'].plot();

# %%
#Média de retorno diária
wege_df['RL Close'].mean()
# Out:
# 0.0009231380960638375

# %%
wege_df['RL Close'].mean() * 100
# Out:
# 0.09231380960638376

# %%
#Média de retorno anual
(wege_df['RL Close'].mean() * 246) * 100
# Out:
# 22.7091971631704

# %%
plt.style.use('seaborn-darkgrid')
plt.figure( figsize=(16, 5) )
plt.title('Análise das ações da WEGE - Fechamento', fontsize=15, loc='left')
plt.plot( wege_df.index, wege_df['Close'] )

plt.xlabel('Período da Cotação')
plt.ylabel('Valor da Ação (R$)');
# Out:
# <ipython-input-46-4017e74d48d0>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
Media_Movel = wege_df['Close'].rolling(5).mean()
Media_Tendencia = wege_df['Close'].rolling(30).mean()

plt.style.use('seaborn-darkgrid')
plt.figure( figsize=(16, 5) )
plt.title('Análise das ações da WEGE - Fechamento', fontsize=15, loc='left')

plt.plot( wege_df.index, wege_df['Close'] )
plt.plot( wege_df.index, Media_Movel )
plt.plot( wege_df.index, Media_Tendencia )

plt.xlabel('Período da Coração')
plt.ylabel('Valor da Ação (R$)');
# Out:
# <ipython-input-47-0e276913a322>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
sns.boxplot( data=wege_df, x='Close')
# Out:
# <Axes: xlabel='Close'>

# %%
Grafico = go.Figure(
    data=[
          go.Candlestick(
              x= wege_df.index,
              open = wege_df['Open'],
              high = wege_df['High'],
              low = wege_df['Low'],
              close = wege_df['Close'],
          )
    ]
)

Grafico.update_layout( xaxis_rangeslider_visible=False )

Grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
